# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# %%
x = [10, 20, 30, 40, 50]
y = [29, 639, 3042, 9296, 25000]

# %%
plt.plot(x, y)
plt.xlabel("number of carbons")
plt.ylabel("time to calculate fock matrix")
# Out:
# Text(0, 0.5, 'time to calculate fock matrix')

# %%
p = np.poly1d(np.polyfit(x, y, deg = 4))
print(p)
# Out:
#          4         3         2
# 0.01475 x - 1.132 x + 40.02 x - 568.4 x + 2695

# %%
totalx = [10, 20, 30, 40, 50, 100, 150, 200, 250, 333]
fock = [1, 5, 17, 26, 41, 169, 467, 1047, 1231, 1993]
density = [0, 3, 6, 16, 32, 404, 2190, 3200, 5124, 11700]
# ham = [0, 1, 4, 7, 12, 63, 59, 66, 992]

# %%
plt.plot(totalx, fock)
plt.xlabel("number of carbons")
plt.ylabel("time to calculate fock matrix")
# Out:
# Text(0, 0.5, 'time to calculate fock matrix')

# %%
plt.plot(totalx, density)
plt.xlabel("number of carbons")
plt.ylabel("time to calculate density matrix from eigenvectors")
# Out:
# Text(0, 0.5, 'time to calculate density matrix from eigenvectors')
